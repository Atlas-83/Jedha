# %% [markdown]
# (base) Atlas-Mbp jedha # ls
# B_oop_dafs_ft_15.ipynb	readme.md
#
# (base) Atlas-Mbp jedha # pwd
# /Users/emmanuelfabre/jedha
#
# (base) Atlas-Mbp jedha # git clone https://github.com/toto-blanco/Prompt_Generator.git
# Clonage dans 'Prompt_Generator'...
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 16 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# Réception d'objets: 100% (16/16), 40.00 Kio | 2.10 Mio/s, fait.
# Résolution des deltas: 100% (1/1), fait.
#
# (base) Atlas-Mbp jedha # git branch
# * main
#
# (base) Atlas-Mbp jedha # git branch salut_vieille_branche
#
# (base) Atlas-Mbp jedha # git branch
# * main
#   salut_vieille_branche
#
# (base) Atlas-Mbp jedha # git checkout salut_vieille_branche
# A	B_oop_dafs_ft_15.ipynb
# M	readme.md
# Basculement sur la branche 'salut_vieille_branche'
#
# (base) Atlas-Mbp jedha # git branch
#   main
# * salut_vieille_branche
#
# (base) Atlas-Mbp jedha # touch manu_branche.ipynb
#
# (base) Atlas-Mbp jedha # git status
# Sur la branche salut_vieille_branche
# Modifications qui seront validées :
#   (utilisez "git restore --staged <fichier>..." pour désindexer)
# 	nouveau fichier : B_oop_dafs_ft_15.ipynb
# 	modifié :         readme.md
#
# Fichiers non suivis:
#   (utilisez "git add <fichier>..." pour inclure dans ce qui sera validé)
# 	Manu.ipynb
# 	Prompt_Generator/
# 	manu_branche.ipynb
